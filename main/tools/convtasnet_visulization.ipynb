# %% [markdown]
# # extract log

# %%
# coding=utf-8
# 该文件用来提取训练log，去除不可解析的log后使log文件格式化，生成新的log文件供可视化工具绘图
 
import inspect
import os
import random
import sys
def extract_log(log_file,new_log_file,key_word):
    with open(log_file, 'r') as f:
        with open(new_log_file, 'w') as train_log:
            i = 0
            for line in f:
#                 print('line: ', line)
        # 去除多gpu的同步log
                if 'Syncing' in line:
                    continue
        # 去除除零错误的log
                if 'nan' in line:
                    continue
                if key_word in line:
                    train_log.write(line)
                    i = i + 1
#             print('{} lines: {}').format(key_word, i)
    f.close()
    train_log.close()
    
extract_log(r'//media/denoiser/Toshibha-3.0TB/MS_SL1_1DBPF_new2/trainer.log',r'/media/denoiser/Toshibha-3.0TB/MS_SL1_1DBPF_new2/train_log_loss.txt','Epoch')
# extract_log('trainer.log','train_log_iou.txt','IOU')

# ————————————————



# 版权声明：本文为CSDN博主「dspeia」的原创文章，遵循 CC 4.0 BY-SA 版权协议，转载请附上原文出处链接及本声明。
# 原文链接：https://blog.csdn.net/qq_34806812/article/details/81459982

# %% [markdown]
# # loss visulization

# %%
#!/usr/bin/python
#coding=utf-8
 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

startEpoch = 0
endEpoch = 200
with open(r'/media/denoiser/Toshibha-3.0TB/MS_SL1_1DBPF_new2/train_log_loss.txt', 'r') as f:
    epoch = []
    train_loss = []
    valid_loss = []
    for lineNum, line in enumerate(f):
        try:
            if lineNum < 10:
                epoch.append(int(line.split(' ')[11].split(':')[0]))
                train_loss.append(float(line.split(' ')[14].split('(')[0]))
                valid_loss.append(float(line.split(' ')[18].split('(')[0]))
            else:

                epoch.append(int(line.split(' ')[10].split(':')[0]))
                train_loss.append(float(line.split(' ')[13].split('(')[0]))
                valid_loss.append(float(line.split(' ')[17].split('(')[0]))
        except:
            pass

fig, ax1 = plt.subplots(1, 1)
plt.xlabel('Epoch')
plt.ylabel('loss')
ax1.scatter(epoch[startEpoch:endEpoch], train_loss[startEpoch:endEpoch], c='b',  label='train')
ax1.scatter(epoch[startEpoch:endEpoch],valid_loss[startEpoch:endEpoch], c='r', label='validation')
plt.legend(loc='upper right');
# plt.savefig(r'/home/speechsever/MS_SL3_splite_fusion_expo_group_tranferLearning/loss.jpg')
plt.show()

# %%
# coding=utf-8
# 该文件用来提取训练log，去除不可解析的log后使log文件格式化，生成新的log文件供可视化工具绘图
 
import inspect
import os
import random
import sys
def extract_log(log_file,new_log_file,key_word):
    with open(log_file, 'r') as f:
        with open(new_log_file, 'w') as train_log:
            i = 0
            for line in f:
#                 print('line: ', line)
        # 去除多gpu的同步log
                if 'Syncing' in line:
                    continue
        # 去除除零错误的log
                if 'nan' in line:
                    continue
                if key_word in line:
                    train_log.write(line)
                    i = i + 1
#             print('{} lines: {}').format(key_word, i)
    f.close()
    train_log.close()
    
extract_log(r'//media/denoiser/Toshibha-3.0TB/MS_SL2_Fusion_chw_bpf/trainer.log',r'/media/denoiser/Toshibha-3.0TB/MS_SL2_Fusion_chw_bpf/train_log_loss.txt','Epoch')
# extract_log('trainer.log','train_log_iou.txt','IOU')

# ————————————————



# 版权声明：本文为CSDN博主「dspeia」的原创文章，遵循 CC 4.0 BY-SA 版权协议，转载请附上原文出处链接及本声明。
# 原文链接：https://blog.csdn.net/qq_34806812/article/details/81459982

# %%
#!/usr/bin/python
#coding=utf-8
 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

startEpoch = 0
endEpoch = 200
with open(r'/media/denoiser/Toshibha-3.0TB/MS_SL2_Fusion_chw_bpf/train_log_loss.txt', 'r') as f:
    epoch = []
    train_loss = []
    valid_loss = []
    for lineNum, line in enumerate(f):
        try:
            if lineNum < 10:
                epoch.append(int(line.split(' ')[11].split(':')[0]))
                train_loss.append(float(line.split(' ')[14].split('(')[0]))
                valid_loss.append(float(line.split(' ')[18].split('(')[0]))
            else:

                epoch.append(int(line.split(' ')[10].split(':')[0]))
                train_loss.append(float(line.split(' ')[13].split('(')[0]))
                valid_loss.append(float(line.split(' ')[17].split('(')[0]))
        except:
            pass

fig, ax1 = plt.subplots(1, 1)
plt.xlabel('Epoch')
plt.ylabel('loss')
ax1.scatter(epoch[startEpoch:endEpoch], train_loss[startEpoch:endEpoch], c='b',  label='train')
ax1.scatter(epoch[startEpoch:endEpoch],valid_loss[startEpoch:endEpoch], c='r', label='validation')
plt.legend(loc='upper right');
# plt.savefig(r'/home/speechsever/MS_SL3_splite_fusion_expo_group_tranferLearning/loss.jpg')
plt.show()

# %%
valid_loss[-10:]
# Out:
# [-13.3359,
#  -13.4044,
#  -13.3718,
#  -13.2888,
#  -13.3634,
#  -13.5447,
#  -13.5432,
#  -13.4594,
#  -13.52,
#  -13.6939]

# %%
train_loss[-10:]
# Out:
# [-13.6613,
#  -13.6752,
#  -13.6886,
#  -13.6984,
#  -13.718,
#  -13.9299,
#  -13.9622,
#  -13.979,
#  -13.9908,
#  -14.1221]

# %%
# coding=utf-8
# 该文件用来提取训练log，去除不可解析的log后使log文件格式化，生成新的log文件供可视化工具绘图
 
import inspect
import os
import random
import sys
def extract_log(log_file,new_log_file,key_word):
    with open(log_file, 'r') as f:
        with open(new_log_file, 'w') as train_log:
            i = 0
            for line in f:
#                 print('line: ', line)
        # 去除多gpu的同步log
                if 'Syncing' in line:
                    continue
        # 去除除零错误的log
                if 'nan' in line:
                    continue
                if key_word in line:
                    train_log.write(line)
                    i = i + 1
#             print('{} lines: {}').format(key_word, i)
    f.close()
    train_log.close()
    
extract_log(r'/media/denoiser/Toshibha-3.0TB/MS_SL2_Fusion_chw/trainer.log',r'/media/denoiser/Toshibha-3.0TB/MS_SL2_Fusion_chw/train_log_loss.txt','Epoch')
# extract_log('trainer.log','train_log_iou.txt','IOU')

# ————————————————



# 版权声明：本文为CSDN博主「dspeia」的原创文章，遵循 CC 4.0 BY-SA 版权协议，转载请附上原文出处链接及本声明。
# 原文链接：https://blog.csdn.net/qq_34806812/article/details/81459982

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

startEpoch = 0
endEpoch = 200
with open(r'/media/denoiser/Toshibha-3.0TB/MS_SL2_Fusion_chw/train_log_loss.txt', 'r') as f:
    epoch = []
    train_loss = []
    valid_loss = []
    for lineNum, line in enumerate(f):
        try:
            if lineNum < 10:
                epoch.append(int(line.split(' ')[11].split(':')[0]))
                train_loss.append(float(line.split(' ')[14].split('(')[0]))
                valid_loss.append(float(line.split(' ')[18].split('(')[0]))
            else:

                epoch.append(int(line.split(' ')[10].split(':')[0]))
                train_loss.append(float(line.split(' ')[13].split('(')[0]))
                valid_loss.append(float(line.split(' ')[17].split('(')[0]))
        except:
            pass

fig, ax1 = plt.subplots(1, 1)
plt.xlabel('Epoch')
plt.ylabel('loss')
ax1.scatter(epoch[startEpoch:endEpoch], train_loss[startEpoch:endEpoch],  c='b')
ax1.scatter(epoch[startEpoch:endEpoch],valid_loss[startEpoch:endEpoch], c='r')
ax1.plot(epoch[startEpoch:endEpoch], train_loss[startEpoch:endEpoch],c = 'b', label='train')
ax1.plot(epoch[startEpoch:endEpoch],valid_loss[startEpoch:endEpoch],c = 'r', label='validation')
plt.legend(loc='upper right');
# plt.savefig(r'/home/speechsever/MS_SL3_splite_fusion_expo_group_tranferLearning/loss.jpg')
plt.show()
fig.tight_layout()

# %%
train_loss[-10:]
# Out:
# [-9.3023,
#  -10.9975,
#  -11.5102,
#  -11.7725,
#  -11.9535,
#  -12.1986,
#  -12.3083,
#  -12.4139,
#  -12.4525]

# %%
valid_loss[-10:]
# Out:
# [-11.0968,
#  -11.735,
#  -12.018,
#  -12.1993,
#  -12.1359,
#  -12.4976,
#  -12.7881,
#  -12.6287,
#  -12.7282]

# %%
import inspect
import os
import random
import sys
def extract_log(log_file,new_log_file,key_word):
    with open(log_file, 'r') as f:
        with open(new_log_file, 'w') as train_log:
            i = 0
            for line in f:
#                 print('line: ', line)
        # 去除多gpu的同步log
                if 'Syncing' in line:
                    continue
        # 去除除零错误的log
                if 'nan' in line:
                    continue
                if key_word in line:
                    train_log.write(line)
                    i = i + 1
#             print('{} lines: {}').format(key_word, i)
    f.close()
    train_log.close()
    
extract_log(r'/media/speechsever/Toshibha-3.0TB/ai_MS_SL2_only_attention_saved_models/trainer.log',r'/media/speechsever/Toshibha-3.0TB/ai_MS_SL2_only_attention_saved_models/train_log_loss.txt','Epoch')
# extract_log('trainer.log','train_log_iou.txt','IOU')

# ————————————————

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

startEpoch = 0
endEpoch = 200
with open(r'/media/speechsever/Toshibha-3.0TB/ai_MS_SL2_only_attention_saved_models/train_log_loss.txt', 'r') as f:
    epoch = []
    train_loss = []
    valid_loss = []
    for lineNum, line in enumerate(f):
        try:
            if lineNum < 10:
                epoch.append(int(line.split(' ')[11].split(':')[0]))
                train_loss.append(float(line.split(' ')[14].split('(')[0]))
                valid_loss.append(float(line.split(' ')[18].split('(')[0]))
            else:

                epoch.append(int(line.split(' ')[10].split(':')[0]))
                train_loss.append(float(line.split(' ')[13].split('(')[0]))
                valid_loss.append(float(line.split(' ')[17].split('(')[0]))
        except:
            pass

fig, ax1 = plt.subplots(1, 1)
plt.xlabel('Epoch')
plt.ylabel('loss')
ax1.scatter(epoch[startEpoch:endEpoch], train_loss[startEpoch:endEpoch],  c='b')
ax1.scatter(epoch[startEpoch:endEpoch],valid_loss[startEpoch:endEpoch], c='r')
ax1.plot(epoch[startEpoch:endEpoch], train_loss[startEpoch:endEpoch],c = 'b', label='train')
ax1.plot(epoch[startEpoch:endEpoch],valid_loss[startEpoch:endEpoch],c = 'r', label='validation')
plt.legend(loc='upper right');
# plt.savefig(r'/home/speechsever/MS_SL3_splite_fusion_expo_group_tranferLearning/loss.jpg')
plt.show()
fig.tight_layout()

# %%
import inspect
import os
import random
import sys
def extract_log(log_file,new_log_file,key_word):
    with open(log_file, 'r') as f:
        with open(new_log_file, 'w') as train_log:
            i = 0
            for line in f:
#                 print('line: ', line)
        # 去除多gpu的同步log
                if 'Syncing' in line:
                    continue
        # 去除除零错误的log
                if 'nan' in line:
                    continue
                if key_word in line:
                    train_log.write(line)
                    i = i + 1
#             print('{} lines: {}').format(key_word, i)
    f.close()
    train_log.close()
    
extract_log(r'/media/speechsever/Toshibha-3.0TB/MS_SL2_splite_fusion_expo_group/trainer.log',r'/media/speechsever/Toshibha-3.0TB/MS_SL2_splite_fusion_expo_group/train_log_loss.txt','Epoch')
# extract_log('trainer.log','train_log_iou.txt','IOU')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

startEpoch = 0
endEpoch = 200
with open(r'/media/speechsever/Toshibha-3.0TB/MS_SL2_splite_fusion_expo_group/train_log_loss.txt', 'r') as f:
    epoch = []
    train_loss = []
    valid_loss = []
    for lineNum, line in enumerate(f):
        try:
            if lineNum < 10:
                epoch.append(int(line.split(' ')[11].split(':')[0]))
                train_loss.append(float(line.split(' ')[14].split('(')[0]))
                valid_loss.append(float(line.split(' ')[18].split('(')[0]))
            else:

                epoch.append(int(line.split(' ')[10].split(':')[0]))
                train_loss.append(float(line.split(' ')[13].split('(')[0]))
                valid_loss.append(float(line.split(' ')[17].split('(')[0]))
        except:
            pass

fig, ax1 = plt.subplots(1, 1)
plt.xlabel('Epoch')
plt.ylabel('loss')
ax1.scatter(epoch[startEpoch:endEpoch], train_loss[startEpoch:endEpoch],  c='b')
ax1.scatter(epoch[startEpoch:endEpoch],valid_loss[startEpoch:endEpoch], c='r')
ax1.plot(epoch[startEpoch:endEpoch], train_loss[startEpoch:endEpoch],c = 'b', label='train')
ax1.plot(epoch[startEpoch:endEpoch],valid_loss[startEpoch:endEpoch],c = 'r', label='validation')
plt.legend(loc='upper right');
# plt.savefig(r'/home/speechsever/MS_SL3_splite_fusion_expo_group_tranferLearning/loss.jpg')
plt.show()
fig.tight_layout()

# %%
import inspect
import os
import random
import sys
def extract_log(log_file,new_log_file,key_word):
    with open(log_file, 'r') as f:
        with open(new_log_file, 'w') as train_log:
            i = 0
            for line in f:
#                 print('line: ', line)
        # 去除多gpu的同步log
                if 'Syncing' in line:
                    continue
        # 去除除零错误的log
                if 'nan' in line:
                    continue
                if key_word in line:
                    train_log.write(line)
                    i = i + 1
#             print('{} lines: {}').format(key_word, i)
    f.close()
    train_log.close()
    
extract_log(r'/media/denoiser/Toshibha-3.0TB/MS_SL1_3layerrun_models_little_test/trainer.log',r'/media/denoiser/Toshibha-3.0TB/MS_SL1_3layerrun_models_little_test/train_log_loss.txt','Epoch')
# extract_log('trainer.log','train_log_iou.txt','IOU')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

startEpoch = 0
endEpoch = 200
with open(r'/media/denoiser/Toshibha-3.0TB/MS_SL1_3layerrun_models_little_test/train_log_loss.txt', 'r') as f:
    epoch = []
    train_loss = []
    valid_loss = []
    for lineNum, line in enumerate(f):
        try:
            if lineNum < 10:
                epoch.append(int(line.split(' ')[11].split(':')[0]))
                train_loss.append(float(line.split(' ')[14].split('(')[0]))
                valid_loss.append(float(line.split(' ')[18].split('(')[0]))
            else:

                epoch.append(int(line.split(' ')[10].split(':')[0]))
                train_loss.append(float(line.split(' ')[13].split('(')[0]))
                valid_loss.append(float(line.split(' ')[17].split('(')[0]))
        except:
            pass

fig, ax1 = plt.subplots(1, 1)
plt.xlabel('Epoch')
plt.ylabel('loss')
ax1.scatter(epoch[startEpoch:endEpoch], train_loss[startEpoch:endEpoch],  c='b')
ax1.scatter(epoch[startEpoch:endEpoch],valid_loss[startEpoch:endEpoch], c='r')
ax1.plot(epoch[startEpoch:endEpoch], train_loss[startEpoch:endEpoch],c = 'b', label='train')
ax1.plot(epoch[startEpoch:endEpoch],valid_loss[startEpoch:endEpoch],c = 'r', label='validation')
plt.legend(loc='upper right');
# plt.savefig(r'/home/speechsever/MS_SL3_splite_fusion_expo_group_tranferLearning/loss.jpg')
plt.show()
fig.tight_layout()

# %%
import inspect
import os
import random
import sys
def extract_log(log_file,new_log_file,key_word):
    with open(log_file, 'r') as f:
        with open(new_log_file, 'w') as train_log:
            i = 0
            for line in f:
#                 print('line: ', line)
        # 去除多gpu的同步log
                if 'Syncing' in line:
                    continue
        # 去除除零错误的log
                if 'nan' in line:
                    continue
                if key_word in line:
                    train_log.write(line)
                    i = i + 1
#             print('{} lines: {}').format(key_word, i)
    f.close()
    train_log.close()
    
extract_log(r'/media/denoiser/Toshibha-3.0TB/MS_SL2_Fusion_chw_bpf/trainer.log',r'/media/denoiser/Toshibha-3.0TB/MS_SL2_Fusion_chw_bpf/train_log_loss.txt','Epoch')
# extract_log('trainer.log','train_log_iou.txt','IOU')

# ————————————————

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

startEpoch = 0
endEpoch = 200
with open(r'/media/denoiser/Toshibha-3.0TB/MS_SL2_Fusion_chw_bpf/train_log_loss.txt', 'r') as f:
    epoch = []
    train_loss = []
    valid_loss = []
    for lineNum, line in enumerate(f):
        try:
            if lineNum < 10:
                epoch.append(int(line.split(' ')[11].split(':')[0]))
                train_loss.append(float(line.split(' ')[14].split('(')[0]))
                valid_loss.append(float(line.split(' ')[18].split('(')[0]))
            else:

                epoch.append(int(line.split(' ')[10].split(':')[0]))
                train_loss.append(float(line.split(' ')[13].split('(')[0]))
                valid_loss.append(float(line.split(' ')[17].split('(')[0]))
        except:
            pass

fig, ax1 = plt.subplots(1, 1)
plt.xlabel('Epoch')
plt.ylabel('loss')
ax1.scatter(epoch[startEpoch:endEpoch], train_loss[startEpoch:endEpoch],  c='b')
ax1.scatter(epoch[startEpoch:endEpoch],valid_loss[startEpoch:endEpoch], c='r')
ax1.plot(epoch[startEpoch:endEpoch], train_loss[startEpoch:endEpoch],c = 'b', label='train')
ax1.plot(epoch[startEpoch:endEpoch],valid_loss[startEpoch:endEpoch],c = 'r', label='validation')
plt.legend(loc='upper right');
# plt.savefig(r'/home/speechsever/MS_SL3_splite_fusion_expo_group_tranferLearning/loss.jpg')
plt.show()
fig.tight_layout()

# %%
import inspect
import os
import random
import sys
def extract_log(log_file,new_log_file,key_word):
    with open(log_file, 'r') as f:
        with open(new_log_file, 'w') as train_log:
            i = 0
            for line in f:
#                 print('line: ', line)
        # 去除多gpu的同步log
                if 'Syncing' in line:
                    continue
        # 去除除零错误的log
                if 'nan' in line:
                    continue
                if key_word in line:
                    train_log.write(line)
                    i = i + 1
#             print('{} lines: {}').format(key_word, i)
    f.close()
    train_log.close()
    
extract_log(r'/media/denoiser/Toshibha-3.0TB/MS_SL1_mulit_attention_test/trainer.log',r'/media/denoiser/Toshibha-3.0TB/MS_SL1_mulit_attention_test/train_log_loss.txt','Epoch')
# extract_log('trainer.log','train_log_iou.txt','IOU')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

startEpoch = 0
endEpoch = 200
with open(r'/media/denoiser/Toshibha-3.0TB/MS_SL1_mulit_attention_test/train_log_loss.txt', 'r') as f:
    epoch = []
    train_loss = []
    valid_loss = []
    for lineNum, line in enumerate(f):
        try:
            if lineNum < 10:
                epoch.append(int(line.split(' ')[11].split(':')[0]))
                train_loss.append(float(line.split(' ')[14].split('(')[0]))
                valid_loss.append(float(line.split(' ')[18].split('(')[0]))
            else:

                epoch.append(int(line.split(' ')[10].split(':')[0]))
                train_loss.append(float(line.split(' ')[13].split('(')[0]))
                valid_loss.append(float(line.split(' ')[17].split('(')[0]))
        except:
            pass

fig, ax1 = plt.subplots(1, 1)
plt.xlabel('Epoch')
plt.ylabel('loss')
ax1.scatter(epoch[startEpoch:endEpoch], train_loss[startEpoch:endEpoch],  c='b')
ax1.scatter(epoch[startEpoch:endEpoch],valid_loss[startEpoch:endEpoch], c='r')
ax1.plot(epoch[startEpoch:endEpoch], train_loss[startEpoch:endEpoch],c = 'b', label='train')
ax1.plot(epoch[startEpoch:endEpoch],valid_loss[startEpoch:endEpoch],c = 'r', label='validation')
plt.legend(loc='upper right');
# plt.savefig(r'/home/speechsever/MS_SL3_splite_fusion_expo_group_tranferLearning/loss.jpg')
plt.show()
fig.tight_layout()

# %%
import inspect
import os
import random
import sys
def extract_log(log_file,new_log_file,key_word):
    with open(log_file, 'r') as f:
        with open(new_log_file, 'w') as train_log:
            i = 0
            for line in f:
#                 print('line: ', line)
        # 去除多gpu的同步log
                if 'Syncing' in line:
                    continue
        # 去除除零错误的log
                if 'nan' in line:
                    continue
                if key_word in line:
                    train_log.write(line)
                    i = i + 1
#             print('{} lines: {}').format(key_word, i)
    f.close()
    train_log.close()
    
extract_log(r'/media/denoiser/Toshibha-3.0TB/little_test/attention_all_trainer.log',r'/media/denoiser/Toshibha-3.0TB/little_test/attention_all_train_log_loss.txt','Epoch')
# extract_log('trainer.log','train_log_iou.txt','IOU')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

startEpoch = 0
endEpoch = 200
with open(r'/media/denoiser/Toshibha-3.0TB/little_test/attention_all_train_log_loss.txt', 'r') as f:
    epoch = []
    train_loss = []
    valid_loss = []
    for lineNum, line in enumerate(f):
        try:
            if lineNum < 10:
                epoch.append(int(line.split(' ')[11].split(':')[0]))
                train_loss.append(float(line.split(' ')[14].split('(')[0]))
                valid_loss.append(float(line.split(' ')[18].split('(')[0]))
            else:

                epoch.append(int(line.split(' ')[10].split(':')[0]))
                train_loss.append(float(line.split(' ')[13].split('(')[0]))
                valid_loss.append(float(line.split(' ')[17].split('(')[0]))
        except:
            pass

fig, ax1 = plt.subplots(1, 1)
plt.xlabel('Epoch')
plt.ylabel('loss')
ax1.scatter(epoch[startEpoch:endEpoch], train_loss[startEpoch:endEpoch],  c='b')
ax1.scatter(epoch[startEpoch:endEpoch],valid_loss[startEpoch:endEpoch], c='r')
ax1.plot(epoch[startEpoch:endEpoch], train_loss[startEpoch:endEpoch],c = 'b', label='train')
ax1.plot(epoch[startEpoch:endEpoch],valid_loss[startEpoch:endEpoch],c = 'r', label='validation')
plt.legend(loc='upper right');
# plt.savefig(r'/home/speechsever/MS_SL3_splite_fusion_expo_group_tranferLearning/loss.jpg')
plt.show()
fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /media/denoiser/66270bea-3081-4132-b76d-84f0ac1e156e/speech_donoiser_new/main/tools/convtasnet_visulization.ipynb Cell 23 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/media/denoiser/66270bea-3081-4132-b76d-84f0ac1e156e/speech_donoiser_new/main/tools/convtasnet_visulization.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/media/denoiser/66270bea-3081-4132-b76d-84f0ac1e156e/speech_donoiser_new/main/tools/convtasnet_visulization.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a> import numpy as np
#       <a href='vscode-notebook-cell:/media/denoiser/66270bea-3081-4132-b76d-84f0ac1e156e/speech_donoiser_new/main/tools/convtasnet_visulization.ipynb#X31sZmlsZQ%3D%3D?line=2'>3</a> import matplotlib.pyplot as plt
#
# ...

# %%
import inspect
import os
import random
import sys
def extract_log(log_file,new_log_file,key_word):
    with open(log_file, 'r') as f:
        with open(new_log_file, 'w') as train_log:
            i = 0
            for line in f:
#                 print('line: ', line)
        # 去除多gpu的同步log
                if 'Syncing' in line:
                    continue
        # 去除除零错误的log
                if 'nan' in line:
                    continue
                if key_word in line:
                    train_log.write(line)
                    i = i + 1
#             print('{} lines: {}').format(key_word, i)
    f.close()
    train_log.close()
    
extract_log(r'/media/denoiser/Toshibha-3.0TB/MS_SL1_1DBPF_blue_model/trainer.log',r'/media/denoiser/Toshibha-3.0TB/MS_SL1_1DBPF_blue_model/train_log_loss.txt','Epoch')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

startEpoch = 0
endEpoch = 200
with open(r'/media/denoiser/Toshibha-3.0TB/MS_SL1_1DBPF_blue_model/train_log_loss.txt', 'r') as f:
    epoch = []
    train_loss = []
    valid_loss = []
    for lineNum, line in enumerate(f):
        try:
            if lineNum < 10:
                epoch.append(int(line.split(' ')[11].split(':')[0]))
                train_loss.append(float(line.split(' ')[14].split('(')[0]))
                valid_loss.append(float(line.split(' ')[18].split('(')[0]))
            else:

                epoch.append(int(line.split(' ')[10].split(':')[0]))
                train_loss.append(float(line.split(' ')[13].split('(')[0]))
                valid_loss.append(float(line.split(' ')[17].split('(')[0]))
        except:
            pass

fig, ax1 = plt.subplots(1, 1)
plt.xlabel('Epoch')
plt.ylabel('loss')
ax1.scatter(epoch[startEpoch:endEpoch], train_loss[startEpoch:endEpoch],  c='b')
ax1.scatter(epoch[startEpoch:endEpoch],valid_loss[startEpoch:endEpoch], c='r')
ax1.plot(epoch[startEpoch:endEpoch], train_loss[startEpoch:endEpoch],c = 'b', label='train')
ax1.plot(epoch[startEpoch:endEpoch],valid_loss[startEpoch:endEpoch],c = 'r', label='validation')
plt.legend(loc='upper right');
# plt.savefig(r'/home/speechsever/MS_SL3_splite_fusion_expo_group_tranferLearning/loss.jpg')
plt.show()
fig.tight_layout()

# %%
# !pip install numpy==1.20.3
# Out:
# ...
#   Using cached numpy-1.20.3-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.4 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.0
#     Uninstalling numpy-1.20.0:
#       Successfully uninstalled numpy-1.20.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.57.1 requires numpy<1.25,>=1.21, but you have numpy 1.20.3 which is incompatible.
# ...

# %%
import inspect
import os
import random
import sys
def extract_log(log_file,new_log_file,key_word):
    with open(log_file, 'r') as f:
        with open(new_log_file, 'w') as train_log:
            i = 0
            for line in f:
#                 print('line: ', line)
        # 去除多gpu的同步log
                if 'Syncing' in line:
                    continue
        # 去除除零错误的log
                if 'nan' in line:
                    continue
                if key_word in line:
                    train_log.write(line)
                    i = i + 1
#             print('{} lines: {}').format(key_word, i)
    f.close()
    train_log.close()
    
extract_log(r'/media/denoiser/Toshibha-3.0TB/MS_SL1_1DBPF_blue_model/trainer.log',r'/media/denoiser/Toshibha-3.0TB/MS_SL1_1DBPF_blue_model/train_log_loss.txt','Epoch')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

startEpoch = 0
endEpoch = 200
with open(r'/media/denoiser/Toshibha-3.0TB/MS_SL1_1DBPF_model_1/train_log_loss.txt', 'r') as f:
    epoch = []
    train_loss = []
    valid_loss = []
    for lineNum, line in enumerate(f):
        try:
            if lineNum < 10:
                epoch.append(int(line.split(' ')[11].split(':')[0]))
                train_loss.append(float(line.split(' ')[14].split('(')[0]))
                valid_loss.append(float(line.split(' ')[18].split('(')[0]))
            else:

                epoch.append(int(line.split(' ')[10].split(':')[0]))
                train_loss.append(float(line.split(' ')[13].split('(')[0]))
                valid_loss.append(float(line.split(' ')[17].split('(')[0]))
        except:
            pass

fig, ax1 = plt.subplots(1, 1)
plt.xlabel('Epoch')
plt.ylabel('loss')
ax1.scatter(epoch[startEpoch:endEpoch], train_loss[startEpoch:endEpoch],  c='b')
ax1.scatter(epoch[startEpoch:endEpoch],valid_loss[startEpoch:endEpoch], c='r')
ax1.plot(epoch[startEpoch:endEpoch], train_loss[startEpoch:endEpoch],c = 'b', label='train')
ax1.plot(epoch[startEpoch:endEpoch],valid_loss[startEpoch:endEpoch],c = 'r', label='validation')
plt.legend(loc='upper right');
# plt.savefig(r'/home/speechsever/MS_SL3_splite_fusion_expo_group_tranferLearning/loss.jpg')
plt.show()
fig.tight_layout()

# %%
import inspect
import os
import random
import sys
def extract_log(log_file,new_log_file,key_word):
    with open(log_file, 'r') as f:
        with open(new_log_file, 'w') as train_log:
            i = 0
            for line in f:
#                 print('line: ', line)
        # 去除多gpu的同步log
                if 'Syncing' in line:
                    continue
        # 去除除零错误的log
                if 'nan' in line:
                    continue
                if key_word in line:
                    train_log.write(line)
                    i = i + 1
#             print('{} lines: {}').format(key_word, i)
    f.close()
    train_log.close()
    
extract_log(r'/media/denoiser/Toshibha-3.0TB1/CHM_FS_BS4/trainer.log',r'/media/denoiser/Toshibha-3.0TB1/CHM_FS_BS4/train_log_loss.txt','Epoch')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

startEpoch = 0
endEpoch = 200
with open(r'/media/denoiser/Toshibha-3.0TB1/CHM_FS_BS4/train_log_loss.txt', 'r') as f:
    epoch = []
    train_loss = []
    valid_loss = []
    for lineNum, line in enumerate(f):
        try:
            if lineNum < 10:
                epoch.append(int(line.split(' ')[11].split(':')[0]))
                train_loss.append(float(line.split(' ')[14].split('(')[0]))
                valid_loss.append(float(line.split(' ')[18].split('(')[0]))
            else:
                epoch.append(int(line.split(' ')[10].split(':')[0]))
                train_loss.append(float(line.split(' ')[13].split('(')[0]))
                valid_loss.append(float(line.split(' ')[17].split('(')[0]))
        except:
            pass

fig, ax1 = plt.subplots(1, 1)
plt.xlabel('Epoch')
plt.ylabel('Loss')
ax1.scatter(epoch[startEpoch:endEpoch], train_loss[startEpoch:endEpoch],  c='b', marker='o', label='Train ')
ax1.scatter(epoch[startEpoch:endEpoch], valid_loss[startEpoch:endEpoch], c='r', marker='^', label='Validation ')
ax1.plot(epoch[startEpoch:endEpoch], train_loss[startEpoch:endEpoch], c='b')
ax1.plot(epoch[startEpoch:endEpoch], valid_loss[startEpoch:endEpoch], c='r')
plt.legend(loc='upper right')
plt.show()
fig.tight_layout()
